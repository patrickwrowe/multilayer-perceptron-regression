# %%
# %load_ext autoreload
# %autoreload 2

# %%
import dataloader
import modules 
import plots
from trainer import Trainer
import torch 
import matplotlib.pyplot as plt
from matplotlib_style import setup_matplotlib_environment, theme_categorical_bright

# %%
setup_matplotlib_environment()

# %% [markdown]
# # Test on Kaggle Housing Dataset

# %%
def k_fold_data(data, k):
    rets = []
    fold_size = data.train.shape[0] // k
    for j in range(k):
        idx = range(j * fold_size, (j+1) * fold_size)
        rets.append(dataloader.KaggleHouse(data.batch_size, data.train.drop(index=idx),
                                data.train.loc[idx]))
    return rets

def k_fold(trainer, data, network_architecture, k, lr):
    models, data_folds = [], []
    for i, data_fold in enumerate(k_fold_data(data, k)):
        model = modules.LinearReLUMLP(network_architecture, learning_rate=0.01)
        trainer.fit(model, data_fold)
        models.append(model)
        data_folds.append(data_fold)
    return models, data_folds

# %%
data = dataloader.KaggleHouse(batch_size=64)
data.preprocess()

# %%
network_architecture = [32, 32]
model = modules.LinearReLUMLP(network_architecture, learning_rate=0.01)
# Out:
# /Users/patrickrowe/miniconda3/envs/main/lib/python3.12/site-packages/torch/nn/modules/lazy.py:181: UserWarning: Lazy modules are a new feature under heavy development so changes to the API or functionality can happen at any moment.
#   warnings.warn('Lazy modules are a new feature under heavy development '

# %%
trainer = Trainer(max_epochs=50)
trainer.fit(model, data)
# Out:
# Model running on cpu
#
#  EPOCH
#
# Epoch 1/50, Training Loss: 36.4395
#
#  EPOCH
#
# Epoch 2/50, Training Loss: 1.5408
#
#  EPOCH
#
# Epoch 3/50, Training Loss: 0.2203
#
#  EPOCH
#
# Epoch 4/50, Training Loss: 0.0529
#
#  EPOCH
#
# Epoch 5/50, Training Loss: 0.0289
#
#  EPOCH
#
# Epoch 6/50, Training Loss: 0.0218
#
#  EPOCH
#
# Epoch 7/50, Training Loss: 0.0182
#
#  EPOCH
#
# Epoch 8/50, Training Loss: 0.0174
#
#  EPOCH
#
# Epoch 9/50, Training Loss: 0.0143
#
#  EPOCH
#
# Epoch 10/50, Training Loss: 0.0124
#
#  EPOCH
#
# Epoch 11/50, Training Loss: 0.0116
#
#  EPOCH
#
# Epoch 12/50, Training Loss: 0.0111
#
#  EPOCH
#
# Epoch 13/50, Training Loss: 0.0113
#
#  EPOCH
#
# Epoch 14/50, Training Loss: 0.0103
#
#  EPOCH
#
# Epoch 15/50, Training Loss: 0.0105
#
#  EPOCH
#
# Epoch 16/50, Training Loss: 0.0103
#
#  EPOCH
#
# Epoch 17/50, Training Loss: 0.0104
#
#  EPOCH
#
# Epoch 18/50, Training Loss: 0.0108
#
#  EPOCH
#
# Epoch 19/50, Training Loss: 0.0136
#
#  EPOCH
#
# Epoch 20/50, Training Loss: 0.0152
#
#  EPOCH
#
# Epoch 21/50, Training Loss: 0.0109
#
#  EPOCH
#
# Epoch 22/50, Training Loss: 0.0108
#
#  EPOCH
#
# Epoch 23/50, Training Loss: 0.0112
#
#  EPOCH
#
# Epoch 24/50, Training Loss: 0.0115
#
#  EPOCH
#
# Epoch 25/50, Training Loss: 0.0109
#
#  EPOCH
#
# Epoch 26/50, Training Loss: 0.0117
#
#  EPOCH
#
# Epoch 27/50, Training Loss: 0.0139
#
#  EPOCH
#
# Epoch 28/50, Training Loss: 0.0197
#
#  EPOCH
#
# Epoch 29/50, Training Loss: 0.0149
#
#  EPOCH
#
# Epoch 30/50, Training Loss: 0.0150
#
#  EPOCH
#
# Epoch 31/50, Training Loss: 0.0178
#
#  EPOCH
#
# Epoch 32/50, Training Loss: 0.0123
#
#  EPOCH
#
# Epoch 33/50, Training Loss: 0.0115
#
#  EPOCH
#
# Epoch 34/50, Training Loss: 0.0115
#
#  EPOCH
#
# Epoch 35/50, Training Loss: 0.0108
#
#  EPOCH
#
# Epoch 36/50, Training Loss: 0.0112
#
#  EPOCH
#
# Epoch 37/50, Training Loss: 0.0137
#
#  EPOCH
#
# Epoch 38/50, Training Loss: 0.0169
#
#  EPOCH
#
# Epoch 39/50, Training Loss: 0.0198
#
#  EPOCH
#
# Epoch 40/50, Training Loss: 0.0135
#
#  EPOCH
#
# Epoch 41/50, Training Loss: 0.0136
#
#  EPOCH
#
# Epoch 42/50, Training Loss: 0.0128
#
#  EPOCH
#
# Epoch 43/50, Training Loss: 0.0119
#
#  EPOCH
#
# Epoch 44/50, Training Loss: 0.0117
#
#  EPOCH
#
# Epoch 45/50, Training Loss: 0.0122
#
#  EPOCH
#
# Epoch 46/50, Training Loss: 0.0126
#
#  EPOCH
#
# Epoch 47/50, Training Loss: 0.0144
#
#  EPOCH
#
# Epoch 48/50, Training Loss: 0.0205
#
#  EPOCH
#
# Epoch 49/50, Training Loss: 0.0162
#
#  EPOCH
#
# Epoch 50/50, Training Loss: 0.0282

# %%
y = torch.tensor(data.train["SalePrice"].values.astype(float), dtype=torch.float32)
y_hat = torch.exp(model(torch.tensor(data.train.drop(columns="SalePrice").values.astype(float), dtype=torch.float32)))

fig, ax = plt.subplots(ncols=1, nrows=1)

ax.scatter(y.detach().numpy(), y_hat.detach().numpy(), alpha=0.6, label='Predicted')

# add a line
ax.plot([min(y), max(y)], [min(y), max(y)], color='red', label='Real')

# %%
models, data_folds = k_fold(trainer, data, network_architecture=[32, 32], k=5, lr=0.1)
# Out:
# /Users/patrickrowe/miniconda3/envs/main/lib/python3.12/site-packages/torch/nn/modules/lazy.py:181: UserWarning: Lazy modules are a new feature under heavy development so changes to the API or functionality can happen at any moment.
#   warnings.warn('Lazy modules are a new feature under heavy development '
# Model running on cpu
#
#  EPOCH
#
# Epoch 1/50, Training Loss: 51.9689
# Epoch 1/50, Validation Loss: 2.6753
#
#  EPOCH
#
# Epoch 2/50, Training Loss: 3.8008
# Epoch 2/50, Validation Loss: 0.1581
#
#  EPOCH
#
# Epoch 3/50, Training Loss: 0.5317
# Epoch 3/50, Validation Loss: 0.0789
#
#  EPOCH
#
# Epoch 4/50, Training Loss: 0.1368
# Epoch 4/50, Validation Loss: 0.0845
#
#  EPOCH
#
# Epoch 5/50, Training Loss: 0.0571
# Epoch 5/50, Validation Loss: 0.0542
#
#  EPOCH
#
# Epoch 6/50, Training Loss: 0.0270
# Epoch 6/50, Validation Loss: 0.0297
#
#  EPOCH
#
# Epoch 7/50, Training Loss: 0.0209
# Epoch 7/50, Validation Loss: 0.0238
#
#  EPOCH
#
# Epoch 8/50, Training Loss: 0.0183
# Epoch 8/50, Validation Loss: 0.0251
#
#  EPOCH
#
# Epoch 9/50, Training Loss: 0.0161
# Epoch 9/50, Validation Loss: 0.0198
#
#  EPOCH
#
# Epoch 10/50, Training Loss: 0.0143
# Epoch 10/50, Validation Loss: 0.0183
#
#  EPOCH
#
# Epoch 11/50, Training Loss: 0.0127
# Epoch 11/50, Validation Loss: 0.0206
#
#  EPOCH
#
# Epoch 12/50, Training Loss: 0.0136
# Epoch 12/50, Validation Loss: 0.0208
#
#  EPOCH
#
# Epoch 13/50, Training Loss: 0.0187
# Epoch 13/50, Validation Loss: 0.0196
#
#  EPOCH
#
# Epoch 14/50, Training Loss: 0.0194
# Epoch 14/50, Validation Loss: 0.0159
#
#  EPOCH
#
# Epoch 15/50, Training Loss: 0.0133
# Epoch 15/50, Validation Loss: 0.0192
#
#  EPOCH
#
# Epoch 16/50, Training Loss: 0.0110
# Epoch 16/50, Validation Loss: 0.0182
#
#  EPOCH
#
# Epoch 17/50, Training Loss: 0.0101
# Epoch 17/50, Validation Loss: 0.0167
#
#  EPOCH
#
# Epoch 18/50, Training Loss: 0.0101
# Epoch 18/50, Validation Loss: 0.0177
#
#  EPOCH
#
# Epoch 19/50, Training Loss: 0.0108
# Epoch 19/50, Validation Loss: 0.0195
#
#  EPOCH
#
# Epoch 20/50, Training Loss: 0.0102
# Epoch 20/50, Validation Loss: 0.0167
#
#  EPOCH
#
# Epoch 21/50, Training Loss: 0.0096
# Epoch 21/50, Validation Loss: 0.0179
#
#  EPOCH
#
# Epoch 22/50, Training Loss: 0.0098
# Epoch 22/50, Validation Loss: 0.0178
#
#  EPOCH
#
# Epoch 23/50, Training Loss: 0.0117
# Epoch 23/50, Validation Loss: 0.0178
#
#  EPOCH
#
# Epoch 24/50, Training Loss: 0.0127
# Epoch 24/50, Validation Loss: 0.0174
#
#  EPOCH
#
# Epoch 25/50, Training Loss: 0.0108
# Epoch 25/50, Validation Loss: 0.0177
#
#  EPOCH
#
# Epoch 26/50, Training Loss: 0.0106
# Epoch 26/50, Validation Loss: 0.0187
#
#  EPOCH
#
# Epoch 27/50, Training Loss: 0.0110
# Epoch 27/50, Validation Loss: 0.0191
#
#  EPOCH
#
# Epoch 28/50, Training Loss: 0.0105
# Epoch 28/50, Validation Loss: 0.0202
#
#  EPOCH
#
# Epoch 29/50, Training Loss: 0.0118
# Epoch 29/50, Validation Loss: 0.0219
#
#  EPOCH
#
# Epoch 30/50, Training Loss: 0.0108
# Epoch 30/50, Validation Loss: 0.0225
#
#  EPOCH
#
# Epoch 31/50, Training Loss: 0.0115
# Epoch 31/50, Validation Loss: 0.0180
#
#  EPOCH
#
# Epoch 32/50, Training Loss: 0.0102
# Epoch 32/50, Validation Loss: 0.0173
#
#  EPOCH
#
# Epoch 33/50, Training Loss: 0.0112
# Epoch 33/50, Validation Loss: 0.0199
#
#  EPOCH
#
# Epoch 34/50, Training Loss: 0.0156
# Epoch 34/50, Validation Loss: 0.0216
#
#  EPOCH
#
# Epoch 35/50, Training Loss: 0.0118
# Epoch 35/50, Validation Loss: 0.0206
#
#  EPOCH
#
# Epoch 36/50, Training Loss: 0.0107
# Epoch 36/50, Validation Loss: 0.0179
#
#  EPOCH
#
# Epoch 37/50, Training Loss: 0.0098
# Epoch 37/50, Validation Loss: 0.0199
#
#  EPOCH
#
# Epoch 38/50, Training Loss: 0.0100
# Epoch 38/50, Validation Loss: 0.0180
#
#  EPOCH
#
# Epoch 39/50, Training Loss: 0.0102
# Epoch 39/50, Validation Loss: 0.0201
#
#  EPOCH
#
# Epoch 40/50, Training Loss: 0.0100
# Epoch 40/50, Validation Loss: 0.0180
#
#  EPOCH
#
# Epoch 41/50, Training Loss: 0.0101
# Epoch 41/50, Validation Loss: 0.0192
#
#  EPOCH
#
# Epoch 42/50, Training Loss: 0.0106
# Epoch 42/50, Validation Loss: 0.0173
#
#  EPOCH
#
# Epoch 43/50, Training Loss: 0.0108
# Epoch 43/50, Validation Loss: 0.0198
#
#  EPOCH
#
# Epoch 44/50, Training Loss: 0.0111
# Epoch 44/50, Validation Loss: 0.0212
#
#  EPOCH
#
# Epoch 45/50, Training Loss: 0.0101
# Epoch 45/50, Validation Loss: 0.0195
#
#  EPOCH
#
# Epoch 46/50, Training Loss: 0.0110
# Epoch 46/50, Validation Loss: 0.0199
#
#  EPOCH
#
# Epoch 47/50, Training Loss: 0.0121
# Epoch 47/50, Validation Loss: 0.0227
#
#  EPOCH
#
# Epoch 48/50, Training Loss: 0.0109
# Epoch 48/50, Validation Loss: 0.0223
#
#  EPOCH
#
# Epoch 49/50, Training Loss: 0.0112
# Epoch 49/50, Validation Loss: 0.0202
#
#  EPOCH
#
# Epoch 50/50, Training Loss: 0.0116
# Epoch 50/50, Validation Loss: 0.0214
# Model running on cpu
#
#  EPOCH
#
# Epoch 1/50, Training Loss: 42.6467
# Epoch 1/50, Validation Loss: 11.0021
#
#  EPOCH
#
# Epoch 2/50, Training Loss: 3.3419
# Epoch 2/50, Validation Loss: 1.9499
#
#  EPOCH
# /Users/patrickrowe/miniconda3/envs/main/lib/python3.12/site-packages/torch/nn/modules/lazy.py:181: UserWarning: Lazy modules are a new feature under heavy development so changes to the API or functionality can happen at any moment.
#   warnings.warn('Lazy modules are a new feature under heavy development '
# Epoch 3/50, Training Loss: 0.5956
# Epoch 3/50, Validation Loss: 0.2556
#
#  EPOCH
#
# Epoch 4/50, Training Loss: 0.1182
# Epoch 4/50, Validation Loss: 0.0664
#
#  EPOCH
#
# Epoch 5/50, Training Loss: 0.0465
# Epoch 5/50, Validation Loss: 0.0412
#
#  EPOCH
#
# Epoch 6/50, Training Loss: 0.0282
# Epoch 6/50, Validation Loss: 0.0333
#
#  EPOCH
#
# Epoch 7/50, Training Loss: 0.0215
# Epoch 7/50, Validation Loss: 0.0301
#
#  EPOCH
#
# Epoch 8/50, Training Loss: 0.0173
# Epoch 8/50, Validation Loss: 0.0294
#
#  EPOCH
#
# Epoch 9/50, Training Loss: 0.0162
# Epoch 9/50, Validation Loss: 0.0292
#
#  EPOCH
#
# Epoch 10/50, Training Loss: 0.0153
# Epoch 10/50, Validation Loss: 0.0271
#
#  EPOCH
#
# Epoch 11/50, Training Loss: 0.0132
# Epoch 11/50, Validation Loss: 0.0272
#
#  EPOCH
#
# Epoch 12/50, Training Loss: 0.0122
# Epoch 12/50, Validation Loss: 0.0273
#
#  EPOCH
#
# Epoch 13/50, Training Loss: 0.0125
# Epoch 13/50, Validation Loss: 0.0267
#
#  EPOCH
#
# Epoch 14/50, Training Loss: 0.0118
# Epoch 14/50, Validation Loss: 0.0287
#
#  EPOCH
#
# Epoch 15/50, Training Loss: 0.0113
# Epoch 15/50, Validation Loss: 0.0261
#
#  EPOCH
#
# Epoch 16/50, Training Loss: 0.0110
# Epoch 16/50, Validation Loss: 0.0266
#
#  EPOCH
#
# Epoch 17/50, Training Loss: 0.0107
# Epoch 17/50, Validation Loss: 0.0275
#
#  EPOCH
#
# Epoch 18/50, Training Loss: 0.0107
# Epoch 18/50, Validation Loss: 0.0269
#
#  EPOCH
#
# Epoch 19/50, Training Loss: 0.0097
# Epoch 19/50, Validation Loss: 0.0269
#
#  EPOCH
#
# Epoch 20/50, Training Loss: 0.0101
# Epoch 20/50, Validation Loss: 0.0272
#
#  EPOCH
#
# Epoch 21/50, Training Loss: 0.0103
# Epoch 21/50, Validation Loss: 0.0266
#
#  EPOCH
#
# Epoch 22/50, Training Loss: 0.0092
# Epoch 22/50, Validation Loss: 0.0273
#
#  EPOCH
#
# Epoch 23/50, Training Loss: 0.0110
# Epoch 23/50, Validation Loss: 0.0261
#
#  EPOCH
#
# Epoch 24/50, Training Loss: 0.0109
# Epoch 24/50, Validation Loss: 0.0272
#
#  EPOCH
#
# Epoch 25/50, Training Loss: 0.0101
# Epoch 25/50, Validation Loss: 0.0264
#
#  EPOCH
#
# Epoch 26/50, Training Loss: 0.0093
# Epoch 26/50, Validation Loss: 0.0265
#
#  EPOCH
#
# Epoch 27/50, Training Loss: 0.0118
# Epoch 27/50, Validation Loss: 0.0281
#
#  EPOCH
#
# Epoch 28/50, Training Loss: 0.0338
# Epoch 28/50, Validation Loss: 0.0308
#
#  EPOCH
#
# Epoch 29/50, Training Loss: 0.0205
# Epoch 29/50, Validation Loss: 0.0326
#
#  EPOCH
#
# Epoch 30/50, Training Loss: 0.0134
# Epoch 30/50, Validation Loss: 0.0281
#
#  EPOCH
#
# Epoch 31/50, Training Loss: 0.0109
# Epoch 31/50, Validation Loss: 0.0275
#
#  EPOCH
#
# Epoch 32/50, Training Loss: 0.0099
# Epoch 32/50, Validation Loss: 0.0289
#
#  EPOCH
#
# Epoch 33/50, Training Loss: 0.0113
# Epoch 33/50, Validation Loss: 0.0275
#
#  EPOCH
#
# Epoch 34/50, Training Loss: 0.0114
# Epoch 34/50, Validation Loss: 0.0289
#
#  EPOCH
#
# Epoch 35/50, Training Loss: 0.0115
# Epoch 35/50, Validation Loss: 0.0282
#
#  EPOCH
#
# Epoch 36/50, Training Loss: 0.0107
# Epoch 36/50, Validation Loss: 0.0284
#
#  EPOCH
#
# Epoch 37/50, Training Loss: 0.0122
# Epoch 37/50, Validation Loss: 0.0276
#
#  EPOCH
#
# Epoch 38/50, Training Loss: 0.0118
# Epoch 38/50, Validation Loss: 0.0283
#
#  EPOCH
#
# Epoch 39/50, Training Loss: 0.0126
# Epoch 39/50, Validation Loss: 0.0279
#
#  EPOCH
#
# Epoch 40/50, Training Loss: 0.0111
# Epoch 40/50, Validation Loss: 0.0286
#
#  EPOCH
#
# Epoch 41/50, Training Loss: 0.0102
# Epoch 41/50, Validation Loss: 0.0273
#
#  EPOCH
#
# Epoch 42/50, Training Loss: 0.0095
# Epoch 42/50, Validation Loss: 0.0273
#
#  EPOCH
#
# Epoch 43/50, Training Loss: 0.0090
# Epoch 43/50, Validation Loss: 0.0264
#
#  EPOCH
#
# Epoch 44/50, Training Loss: 0.0105
# Epoch 44/50, Validation Loss: 0.0278
#
#  EPOCH
#
# Epoch 45/50, Training Loss: 0.0116
# Epoch 45/50, Validation Loss: 0.0289
#
#  EPOCH
#
# Epoch 46/50, Training Loss: 0.0109
# Epoch 46/50, Validation Loss: 0.0278
#
#  EPOCH
#
# Epoch 47/50, Training Loss: 0.0102
# Epoch 47/50, Validation Loss: 0.0307
#
#  EPOCH
#
# Epoch 48/50, Training Loss: 0.0113
# Epoch 48/50, Validation Loss: 0.0296
#
#  EPOCH
#
# Epoch 49/50, Training Loss: 0.0107
# Epoch 49/50, Validation Loss: 0.0333
#
#  EPOCH
#
# Epoch 50/50, Training Loss: 0.0109
# Epoch 50/50, Validation Loss: 0.0272
# Model running on cpu
#
#  EPOCH
#
# Epoch 1/50, Training Loss: 53.4541
# Epoch 1/50, Validation Loss: 2.9763
#
#  EPOCH
# /Users/patrickrowe/miniconda3/envs/main/lib/python3.12/site-packages/torch/nn/modules/lazy.py:181: UserWarning: Lazy modules are a new feature under heavy development so changes to the API or functionality can happen at any moment.
#   warnings.warn('Lazy modules are a new feature under heavy development '
# Epoch 2/50, Training Loss: 3.9361
# Epoch 2/50, Validation Loss: 0.2928
#
#  EPOCH
#
# Epoch 3/50, Training Loss: 0.5795
# Epoch 3/50, Validation Loss: 0.1229
#
#  EPOCH
#
# Epoch 4/50, Training Loss: 0.1385
# Epoch 4/50, Validation Loss: 0.1006
#
#  EPOCH
#
# Epoch 5/50, Training Loss: 0.0567
# Epoch 5/50, Validation Loss: 0.0382
#
#  EPOCH
#
# Epoch 6/50, Training Loss: 0.0265
# Epoch 6/50, Validation Loss: 0.0292
#
#  EPOCH
#
# Epoch 7/50, Training Loss: 0.0234
# Epoch 7/50, Validation Loss: 0.0263
#
#  EPOCH
#
# Epoch 8/50, Training Loss: 0.0197
# Epoch 8/50, Validation Loss: 0.0253
#
#  EPOCH
#
# Epoch 9/50, Training Loss: 0.0192
# Epoch 9/50, Validation Loss: 0.0293
#
#  EPOCH
#
# Epoch 10/50, Training Loss: 0.0166
# Epoch 10/50, Validation Loss: 0.0233
#
#  EPOCH
#
# Epoch 11/50, Training Loss: 0.0143
# Epoch 11/50, Validation Loss: 0.0224
#
#  EPOCH
#
# Epoch 12/50, Training Loss: 0.0138
# Epoch 12/50, Validation Loss: 0.0223
#
#  EPOCH
#
# Epoch 13/50, Training Loss: 0.0119
# Epoch 13/50, Validation Loss: 0.0218
#
#  EPOCH
#
# Epoch 14/50, Training Loss: 0.0119
# Epoch 14/50, Validation Loss: 0.0219
#
#  EPOCH
#
# Epoch 15/50, Training Loss: 0.0121
# Epoch 15/50, Validation Loss: 0.0217
#
#  EPOCH
#
# Epoch 16/50, Training Loss: 0.0114
# Epoch 16/50, Validation Loss: 0.0246
#
#  EPOCH
#
# Epoch 17/50, Training Loss: 0.0118
# Epoch 17/50, Validation Loss: 0.0229
#
#  EPOCH
#
# Epoch 18/50, Training Loss: 0.0119
# Epoch 18/50, Validation Loss: 0.0245
#
#  EPOCH
#
# Epoch 19/50, Training Loss: 0.0132
# Epoch 19/50, Validation Loss: 0.0237
#
#  EPOCH
#
# Epoch 20/50, Training Loss: 0.0130
# Epoch 20/50, Validation Loss: 0.0245
#
#  EPOCH
#
# Epoch 21/50, Training Loss: 0.0114
# Epoch 21/50, Validation Loss: 0.0233
#
#  EPOCH
#
# Epoch 22/50, Training Loss: 0.0105
# Epoch 22/50, Validation Loss: 0.0230
#
#  EPOCH
#
# Epoch 23/50, Training Loss: 0.0101
# Epoch 23/50, Validation Loss: 0.0245
#
#  EPOCH
#
# Epoch 24/50, Training Loss: 0.0105
# Epoch 24/50, Validation Loss: 0.0245
#
#  EPOCH
#
# Epoch 25/50, Training Loss: 0.0101
# Epoch 25/50, Validation Loss: 0.0242
#
#  EPOCH
#
# Epoch 26/50, Training Loss: 0.0109
# Epoch 26/50, Validation Loss: 0.0259
#
#  EPOCH
#
# Epoch 27/50, Training Loss: 0.0107
# Epoch 27/50, Validation Loss: 0.0268
#
#  EPOCH
#
# Epoch 28/50, Training Loss: 0.0111
# Epoch 28/50, Validation Loss: 0.0256
#
#  EPOCH
#
# Epoch 29/50, Training Loss: 0.0135
# Epoch 29/50, Validation Loss: 0.0287
#
#  EPOCH
#
# Epoch 30/50, Training Loss: 0.0123
# Epoch 30/50, Validation Loss: 0.0249
#
#  EPOCH
#
# Epoch 31/50, Training Loss: 0.0119
# Epoch 31/50, Validation Loss: 0.0271
#
#  EPOCH
#
# Epoch 32/50, Training Loss: 0.0139
# Epoch 32/50, Validation Loss: 0.0283
#
#  EPOCH
#
# Epoch 33/50, Training Loss: 0.0190
# Epoch 33/50, Validation Loss: 0.0305
#
#  EPOCH
#
# Epoch 34/50, Training Loss: 0.0131
# Epoch 34/50, Validation Loss: 0.0301
#
#  EPOCH
#
# Epoch 35/50, Training Loss: 0.0115
# Epoch 35/50, Validation Loss: 0.0278
#
#  EPOCH
#
# Epoch 36/50, Training Loss: 0.0109
# Epoch 36/50, Validation Loss: 0.0266
#
#  EPOCH
#
# Epoch 37/50, Training Loss: 0.0097
# Epoch 37/50, Validation Loss: 0.0256
#
#  EPOCH
#
# Epoch 38/50, Training Loss: 0.0100
# Epoch 38/50, Validation Loss: 0.0268
#
#  EPOCH
#
# Epoch 39/50, Training Loss: 0.0097
# Epoch 39/50, Validation Loss: 0.0272
#
#  EPOCH
#
# Epoch 40/50, Training Loss: 0.0098
# Epoch 40/50, Validation Loss: 0.0262
#
#  EPOCH
#
# Epoch 41/50, Training Loss: 0.0097
# Epoch 41/50, Validation Loss: 0.0275
#
#  EPOCH
#
# Epoch 42/50, Training Loss: 0.0096
# Epoch 42/50, Validation Loss: 0.0295
#
#  EPOCH
#
# Epoch 43/50, Training Loss: 0.0104
# Epoch 43/50, Validation Loss: 0.0283
#
#  EPOCH
#
# Epoch 44/50, Training Loss: 0.0096
# Epoch 44/50, Validation Loss: 0.0273
#
#  EPOCH
#
# Epoch 45/50, Training Loss: 0.0095
# Epoch 45/50, Validation Loss: 0.0274
#
#  EPOCH
#
# Epoch 46/50, Training Loss: 0.0089
# Epoch 46/50, Validation Loss: 0.0270
#
#  EPOCH
#
# Epoch 47/50, Training Loss: 0.0094
# Epoch 47/50, Validation Loss: 0.0283
#
#  EPOCH
#
# Epoch 48/50, Training Loss: 0.0099
# Epoch 48/50, Validation Loss: 0.0272
#
#  EPOCH
#
# Epoch 49/50, Training Loss: 0.0106
# Epoch 49/50, Validation Loss: 0.0292
#
#  EPOCH
#
# Epoch 50/50, Training Loss: 0.0117
# Epoch 50/50, Validation Loss: 0.0297
# Model running on cpu
#
#  EPOCH
# /Users/patrickrowe/miniconda3/envs/main/lib/python3.12/site-packages/torch/nn/modules/lazy.py:181: UserWarning: Lazy modules are a new feature under heavy development so changes to the API or functionality can happen at any moment.
#   warnings.warn('Lazy modules are a new feature under heavy development '
# Epoch 1/50, Training Loss: 48.5994
# Epoch 1/50, Validation Loss: 9.3989
#
#  EPOCH
#
# Epoch 2/50, Training Loss: 4.2009
# Epoch 2/50, Validation Loss: 1.3552
#
#  EPOCH
#
# Epoch 3/50, Training Loss: 0.6422
# Epoch 3/50, Validation Loss: 0.3172
#
#  EPOCH
#
# Epoch 4/50, Training Loss: 0.1380
# Epoch 4/50, Validation Loss: 0.0487
#
#  EPOCH
#
# Epoch 5/50, Training Loss: 0.0456
# Epoch 5/50, Validation Loss: 0.0329
#
#  EPOCH
#
# Epoch 6/50, Training Loss: 0.0272
# Epoch 6/50, Validation Loss: 0.0216
#
#  EPOCH
#
# Epoch 7/50, Training Loss: 0.0195
# Epoch 7/50, Validation Loss: 0.0191
#
#  EPOCH
#
# Epoch 8/50, Training Loss: 0.0224
# Epoch 8/50, Validation Loss: 0.0189
#
#  EPOCH
#
# Epoch 9/50, Training Loss: 0.0211
# Epoch 9/50, Validation Loss: 0.0171
#
#  EPOCH
#
# Epoch 10/50, Training Loss: 0.0145
# Epoch 10/50, Validation Loss: 0.0145
#
#  EPOCH
#
# Epoch 11/50, Training Loss: 0.0126
# Epoch 11/50, Validation Loss: 0.0132
#
#  EPOCH
#
# Epoch 12/50, Training Loss: 0.0127
# Epoch 12/50, Validation Loss: 0.0145
#
#  EPOCH
#
# Epoch 13/50, Training Loss: 0.0119
# Epoch 13/50, Validation Loss: 0.0120
#
#  EPOCH
#
# Epoch 14/50, Training Loss: 0.0110
# Epoch 14/50, Validation Loss: 0.0123
#
#  EPOCH
#
# Epoch 15/50, Training Loss: 0.0115
# Epoch 15/50, Validation Loss: 0.0119
#
#  EPOCH
#
# Epoch 16/50, Training Loss: 0.0099
# Epoch 16/50, Validation Loss: 0.0119
#
#  EPOCH
#
# Epoch 17/50, Training Loss: 0.0099
# Epoch 17/50, Validation Loss: 0.0130
#
#  EPOCH
#
# Epoch 18/50, Training Loss: 0.0099
# Epoch 18/50, Validation Loss: 0.0119
#
#  EPOCH
#
# Epoch 19/50, Training Loss: 0.0095
# Epoch 19/50, Validation Loss: 0.0127
#
#  EPOCH
#
# Epoch 20/50, Training Loss: 0.0105
# Epoch 20/50, Validation Loss: 0.0127
#
#  EPOCH
#
# Epoch 21/50, Training Loss: 0.0098
# Epoch 21/50, Validation Loss: 0.0124
#
#  EPOCH
#
# Epoch 22/50, Training Loss: 0.0101
# Epoch 22/50, Validation Loss: 0.0129
#
#  EPOCH
#
# Epoch 23/50, Training Loss: 0.0107
# Epoch 23/50, Validation Loss: 0.0128
#
#  EPOCH
#
# Epoch 24/50, Training Loss: 0.0116
# Epoch 24/50, Validation Loss: 0.0140
#
#  EPOCH
#
# Epoch 25/50, Training Loss: 0.0119
# Epoch 25/50, Validation Loss: 0.0135
#
#  EPOCH
#
# Epoch 26/50, Training Loss: 0.0121
# Epoch 26/50, Validation Loss: 0.0169
#
#  EPOCH
#
# Epoch 27/50, Training Loss: 0.0144
# Epoch 27/50, Validation Loss: 0.0134
#
#  EPOCH
#
# Epoch 28/50, Training Loss: 0.0196
# Epoch 28/50, Validation Loss: 0.0173
#
#  EPOCH
#
# Epoch 29/50, Training Loss: 0.0163
# Epoch 29/50, Validation Loss: 0.0162
#
#  EPOCH
#
# Epoch 30/50, Training Loss: 0.0129
# Epoch 30/50, Validation Loss: 0.0139
#
#  EPOCH
#
# Epoch 31/50, Training Loss: 0.0145
# Epoch 31/50, Validation Loss: 0.0144
#
#  EPOCH
#
# Epoch 32/50, Training Loss: 0.0149
# Epoch 32/50, Validation Loss: 0.0145
#
#  EPOCH
#
# Epoch 33/50, Training Loss: 0.0213
# Epoch 33/50, Validation Loss: 0.0181
#
#  EPOCH
#
# Epoch 34/50, Training Loss: 0.0306
# Epoch 34/50, Validation Loss: 0.0161
#
#  EPOCH
#
# Epoch 35/50, Training Loss: 0.0231
# Epoch 35/50, Validation Loss: 0.0155
#
#  EPOCH
#
# Epoch 36/50, Training Loss: 0.0126
# Epoch 36/50, Validation Loss: 0.0141
#
#  EPOCH
#
# Epoch 37/50, Training Loss: 0.0136
# Epoch 37/50, Validation Loss: 0.0147
#
#  EPOCH
#
# Epoch 38/50, Training Loss: 0.0120
# Epoch 38/50, Validation Loss: 0.0140
#
#  EPOCH
#
# Epoch 39/50, Training Loss: 0.0133
# Epoch 39/50, Validation Loss: 0.0146
#
#  EPOCH
#
# Epoch 40/50, Training Loss: 0.0124
# Epoch 40/50, Validation Loss: 0.0145
#
#  EPOCH
#
# Epoch 41/50, Training Loss: 0.0133
# Epoch 41/50, Validation Loss: 0.0146
#
#  EPOCH
#
# Epoch 42/50, Training Loss: 0.0128
# Epoch 42/50, Validation Loss: 0.0128
#
#  EPOCH
#
# Epoch 43/50, Training Loss: 0.0113
# Epoch 43/50, Validation Loss: 0.0139
#
#  EPOCH
#
# Epoch 44/50, Training Loss: 0.0094
# Epoch 44/50, Validation Loss: 0.0130
#
#  EPOCH
#
# Epoch 45/50, Training Loss: 0.0110
# Epoch 45/50, Validation Loss: 0.0165
#
#  EPOCH
#
# Epoch 46/50, Training Loss: 0.0121
# Epoch 46/50, Validation Loss: 0.0148
#
#  EPOCH
#
# Epoch 47/50, Training Loss: 0.0117
# Epoch 47/50, Validation Loss: 0.0147
#
#  EPOCH
#
# Epoch 48/50, Training Loss: 0.0127
# Epoch 48/50, Validation Loss: 0.0157
#
#  EPOCH
#
# Epoch 49/50, Training Loss: 0.0132
# Epoch 49/50, Validation Loss: 0.0139
#
#  EPOCH
#
# Epoch 50/50, Training Loss: 0.0124
# Epoch 50/50, Validation Loss: 0.0191
# Model running on cpu
#
#  EPOCH
#
# Epoch 1/50, Training Loss: 45.3548
# Epoch 1/50, Validation Loss: 11.4236
#
#  EPOCH
#
# Epoch 2/50, Training Loss: 3.7081
# /Users/patrickrowe/miniconda3/envs/main/lib/python3.12/site-packages/torch/nn/modules/lazy.py:181: UserWarning: Lazy modules are a new feature under heavy development so changes to the API or functionality can happen at any moment.
#   warnings.warn('Lazy modules are a new feature under heavy development '
# Epoch 2/50, Validation Loss: 1.7794
#
#  EPOCH
#
# Epoch 3/50, Training Loss: 0.6070
# Epoch 3/50, Validation Loss: 0.3869
#
#  EPOCH
#
# Epoch 4/50, Training Loss: 0.1127
# Epoch 4/50, Validation Loss: 0.1359
#
#  EPOCH
#
# Epoch 5/50, Training Loss: 0.0490
# Epoch 5/50, Validation Loss: 0.1025
#
#  EPOCH
#
# Epoch 6/50, Training Loss: 0.0304
# Epoch 6/50, Validation Loss: 0.0875
#
#  EPOCH
#
# Epoch 7/50, Training Loss: 0.0229
# Epoch 7/50, Validation Loss: 0.0788
#
#  EPOCH
#
# Epoch 8/50, Training Loss: 0.0190
# Epoch 8/50, Validation Loss: 0.0729
#
#  EPOCH
#
# Epoch 9/50, Training Loss: 0.0163
# Epoch 9/50, Validation Loss: 0.0653
#
#  EPOCH
#
# Epoch 10/50, Training Loss: 0.0144
# Epoch 10/50, Validation Loss: 0.0598
#
#  EPOCH
#
# Epoch 11/50, Training Loss: 0.0136
# Epoch 11/50, Validation Loss: 0.0570
#
#  EPOCH
#
# Epoch 12/50, Training Loss: 0.0126
# Epoch 12/50, Validation Loss: 0.0559
#
#  EPOCH
#
# Epoch 13/50, Training Loss: 0.0124
# Epoch 13/50, Validation Loss: 0.0550
#
#  EPOCH
#
# Epoch 14/50, Training Loss: 0.0123
# Epoch 14/50, Validation Loss: 0.0549
#
#  EPOCH
#
# Epoch 15/50, Training Loss: 0.0115
# Epoch 15/50, Validation Loss: 0.0505
#
#  EPOCH
#
# Epoch 16/50, Training Loss: 0.0109
# Epoch 16/50, Validation Loss: 0.0517
#
#  EPOCH
#
# Epoch 17/50, Training Loss: 0.0108
# Epoch 17/50, Validation Loss: 0.0487
#
#  EPOCH
#
# Epoch 18/50, Training Loss: 0.0118
# Epoch 18/50, Validation Loss: 0.0521
#
#  EPOCH
#
# Epoch 19/50, Training Loss: 0.0156
# Epoch 19/50, Validation Loss: 0.0481
#
#  EPOCH
#
# Epoch 20/50, Training Loss: 0.0175
# Epoch 20/50, Validation Loss: 0.0504
#
#  EPOCH
#
# Epoch 21/50, Training Loss: 0.0175
# Epoch 21/50, Validation Loss: 0.0471
#
#  EPOCH
#
# Epoch 22/50, Training Loss: 0.0141
# Epoch 22/50, Validation Loss: 0.0511
#
#  EPOCH
#
# Epoch 23/50, Training Loss: 0.0129
# Epoch 23/50, Validation Loss: 0.0507
#
#  EPOCH
#
# Epoch 24/50, Training Loss: 0.0109
# Epoch 24/50, Validation Loss: 0.0480
#
#  EPOCH
#
# Epoch 25/50, Training Loss: 0.0105
# Epoch 25/50, Validation Loss: 0.0518
#
#  EPOCH
#
# Epoch 26/50, Training Loss: 0.0108
# Epoch 26/50, Validation Loss: 0.0478
#
#  EPOCH
#
# Epoch 27/50, Training Loss: 0.0111
# Epoch 27/50, Validation Loss: 0.0466
#
#  EPOCH
#
# Epoch 28/50, Training Loss: 0.0127
# Epoch 28/50, Validation Loss: 0.0480
#
#  EPOCH
#
# Epoch 29/50, Training Loss: 0.0109
# Epoch 29/50, Validation Loss: 0.0488
#
#  EPOCH
#
# Epoch 30/50, Training Loss: 0.0116
# Epoch 30/50, Validation Loss: 0.0456
#
#  EPOCH
#
# Epoch 31/50, Training Loss: 0.0133
# Epoch 31/50, Validation Loss: 0.0520
#
#  EPOCH
#
# Epoch 32/50, Training Loss: 0.0135
# Epoch 32/50, Validation Loss: 0.0444
#
#  EPOCH
#
# Epoch 33/50, Training Loss: 0.0123
# Epoch 33/50, Validation Loss: 0.0501
#
#  EPOCH
#
# Epoch 34/50, Training Loss: 0.0114
# Epoch 34/50, Validation Loss: 0.0451
#
#  EPOCH
#
# Epoch 35/50, Training Loss: 0.0113
# Epoch 35/50, Validation Loss: 0.0499
#
#  EPOCH
#
# Epoch 36/50, Training Loss: 0.0133
# Epoch 36/50, Validation Loss: 0.0443
#
#  EPOCH
#
# Epoch 37/50, Training Loss: 0.0112
# Epoch 37/50, Validation Loss: 0.0433
#
#  EPOCH
#
# Epoch 38/50, Training Loss: 0.0108
# Epoch 38/50, Validation Loss: 0.0492
#
#  EPOCH
#
# Epoch 39/50, Training Loss: 0.0112
# Epoch 39/50, Validation Loss: 0.0449
#
#  EPOCH
#
# Epoch 40/50, Training Loss: 0.0116
# Epoch 40/50, Validation Loss: 0.0447
#
#  EPOCH
#
# Epoch 41/50, Training Loss: 0.0124
# Epoch 41/50, Validation Loss: 0.0465
#
#  EPOCH
#
# Epoch 42/50, Training Loss: 0.0125
# Epoch 42/50, Validation Loss: 0.0462
#
#  EPOCH
#
# Epoch 43/50, Training Loss: 0.0116
# Epoch 43/50, Validation Loss: 0.0478
#
#  EPOCH
#
# Epoch 44/50, Training Loss: 0.0131
# Epoch 44/50, Validation Loss: 0.0430
#
#  EPOCH
#
# Epoch 45/50, Training Loss: 0.0147
# Epoch 45/50, Validation Loss: 0.0502
#
#  EPOCH
#
# Epoch 46/50, Training Loss: 0.0179
# Epoch 46/50, Validation Loss: 0.0443
#
#  EPOCH
#
# Epoch 47/50, Training Loss: 0.0193
# Epoch 47/50, Validation Loss: 0.0501
#
#  EPOCH
#
# Epoch 48/50, Training Loss: 0.0201
# Epoch 48/50, Validation Loss: 0.0581
#
#  EPOCH
#
# Epoch 49/50, Training Loss: 0.0201
# Epoch 49/50, Validation Loss: 0.0520
#
#  EPOCH
#
# Epoch 50/50, Training Loss: 0.0177
# Epoch 50/50, Validation Loss: 0.0588

# %%
k_fold_y = []
k_fold_y_hat = []

for i, (model, data_fold) in enumerate(zip(models, data_folds)):
    y = torch.tensor(data_fold.val["SalePrice"].values.astype(float), dtype=torch.float32)
    y_hat = torch.exp(model(torch.tensor(data_fold.val.drop(columns="SalePrice").values.astype(float), dtype=torch.float32)))

    k_fold_y.append(y.detach().numpy())
    k_fold_y_hat.append(y_hat.detach().numpy())

# %%
print(len(k_fold_y), len(k_fold_y_hat))
# Out:
# 5 5

# %%
fig, ax = plt.subplots(ncols=1, nrows=len(k_fold_y), figsize=(5, 5 * len(k_fold_y)), sharex=True, sharey=True)


for i in range(len(k_fold_y)):
    ax[i].scatter(k_fold_y[i], k_fold_y_hat[i], alpha=0.6, marker='.', c=theme_categorical_bright[i], label='Predicted')
    ax[i].plot([min(y), max(y)], [min(y), max(y)], color='red', linestyle='dashed', label='Real')
    ax[i].set_title(f'Fold {i+1}')
    ax[i].set_ylabel('Predicted Price ($)')
    ax[i].set_xlabel('Real Price ($)')
# add a line
